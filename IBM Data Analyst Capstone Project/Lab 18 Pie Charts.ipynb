# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 90.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 122.9 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 84.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 124.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 104.4 MB/s eta 0:00:00
# ...

# %%
# !pip install seaborn

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-11-04 21:01:12--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  64.4MB/s    in 2.4s
#
# 2025-11-04 21:01:15 (64.4 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
df.dropna(subset=['DatabaseWantToWorkWith'], inplace=True)

dffilt = df[['ResponseId','DatabaseWantToWorkWith']].copy() 

dffilt['DatabaseWantToWorkWith'] = dffilt['DatabaseWantToWorkWith'].str.split(';')
dffilt = dffilt.explode('DatabaseWantToWorkWith')
dffilt['DatabaseWantToWorkWith'] = dffilt['DatabaseWantToWorkWith'].str.strip()

# %%
sizes = dffilt['DatabaseWantToWorkWith'].value_counts() 
sizes
# Out:
# DatabaseWantToWorkWith
# PostgreSQL                    24005
# SQLite                        13489
# MySQL                         12269
# MongoDB                       10982
# Redis                         10847
# Microsoft SQL Server           7905
# Elasticsearch                  6246
# MariaDB                        5947
# Dynamodb                       3503
# Supabase                       2930
# Oracle                         2636
# BigQuery                       2554
# Firebase Realtime Database     2536
# Cassandra                      2399
# Cloud Firestore                2119
# Snowflake                      1784
# Cosmos DB                      1764
# Neo4J                          1570
# DuckDB                         1468
# Clickhouse                     1328
# Databricks SQL                 1218
# Cockroachdb                    1157
# InfluxDB                       1090
# H2                             1040
# Microsoft Access                662
# ...

# %%
labels = sizes.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*sizes/sizes.sum()
patches, texts = plt.pie(sizes,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, sizes),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("Job Satisfaction Distribution")

# Display the chart
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
top_devtype = df['DevType'].value_counts().head(10).index
dffilt = df[df['DevType'].isin(top_devtype)]
dffilt
# Out:
#        ResponseId                      MainBranch                 Age  \
# 1               2  I am a developer by profession     35-44 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# 5               6     I code primarily as a hobby  Under 18 years old
# 7               8           I am learning to code     18-24 years old
# ...           ...                             ...                 ...
# 65401       65402  I am a developer by profession     25-34 years old
# 65408       65409  I am a developer by profession     25-34 years old
# 65409       65410  I am a developer by profession     35-44 years old
# 65431       65432  I am a developer by profession     45-54 years old
# 65435       65436  I am a developer by profession     18-24 years old
#
#                                               Employment  \
# 1                                    Employed, full-time
# ...

# %%
category_counts= dffilt.DevType.value_counts()
category_counts = category_counts[0:6]

# %%
# Horizontal bar chart (often better for many categories or long labels)
category_counts.plot.barh()
plt.title('Distribution of DevType')
plt.xlabel('Count')
plt.ylabel('DevType')
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here
df['OpSysProfessional use'].unique()
# Out:
# array(['MacOS', 'Windows', nan, ..., 'ChromeOS;iOS;MacOS;Red Hat;Windows',
#        'Android;MacOS;Windows Subsystem for Linux (WSL)',
#        'BSD;Cygwin;Debian;Fedora;iOS;MacOS;Other Linux-based;Red Hat;Windows;Windows Subsystem for Linux (WSL)'],
#       shape=(1793,), dtype=object)

# %%
dffilt = df[['OpSysProfessional use']].copy()
dffilt
# Out:
#                                    OpSysProfessional use
# 1                                                  MacOS
# 2                                                Windows
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# ...                                                  ...
# 65421                                             Ubuntu
# 65427                                                NaN
# 65431  Debian;iOS;iPadOS;MacOS;Other Linux-based;Ubun...
# 65435                    Fedora;Other Linux-based;Ubuntu
# 65436                                      MacOS;Windows
#
# [42558 rows x 1 columns]

# %%
dffilt['OpSysProfessional use'] = dffilt['OpSysProfessional use'].str.split(';')

# %%
dffilt = dffilt.explode('OpSysProfessional use')

# %%
dffilt['OpSysProfessional use'] = dffilt['OpSysProfessional use'].str.strip()
dffilt
# Out:
#       OpSysProfessional use
# 1                     MacOS
# 2                   Windows
# 3                       NaN
# 4                       NaN
# 5                       NaN
# ...                     ...
# 65435                Fedora
# 65435     Other Linux-based
# 65435                Ubuntu
# 65436                 MacOS
# 65436               Windows
#
# [83620 rows x 1 columns]

# %%
counts = dffilt['OpSysProfessional use'].value_counts()

# %%
labels = counts.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*counts/counts.sum()
patches, texts = plt.pie(counts,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, counts),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("OpSys Professional Distribution")

# Display the chart
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
df.dropna(subset='LanguageHaveWorkedWith',inplace=True)
dffilt = df[['LanguageHaveWorkedWith']].copy()
dffilt
# Out:
#                                   LanguageHaveWorkedWith
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4                C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 5      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# ...                                                  ...
# 65421                     Bash/Shell (all shells);Python
# 65427                                  MATLAB;Python;SQL
# 65431  Bash/Shell (all shells);C;C#;C++;Delphi;Groovy...
# 65435           C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65436   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
#
# [42477 rows x 1 columns]

# %%
dffilt['LanguageHaveWorkedWith'] = dffilt['LanguageHaveWorkedWith'].str.split(';')

# %%
dffilt = dffilt.explode('LanguageHaveWorkedWith')

# %%
dffilt['LanguageHaveWorkedWith'] = dffilt['LanguageHaveWorkedWith'].str.strip()
dffilt
# Out:
#         LanguageHaveWorkedWith
# 1      Bash/Shell (all shells)
# 1                           Go
# 1                     HTML/CSS
# 1                         Java
# 1                   JavaScript
# ...                        ...
# 65436                     Java
# 65436               JavaScript
# 65436                      PHP
# 65436                   Python
# 65436               TypeScript
#
# [243853 rows x 1 columns]

# %%
counts = dffilt['LanguageHaveWorkedWith'].value_counts()
counts = counts[0:6]
labels = counts.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*counts/counts.sum()
patches, texts = plt.pie(counts,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, counts),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("Coding Language Distribution")

# Display the chart
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
df.dropna(subset=['NEWCollabToolsHaveWorkedWith'], inplace=True)
df_filt = df[['NEWCollabToolsHaveWorkedWith']].copy() 
df_filt['NEWCollabToolsHaveWorkedWith'] = df_filt['NEWCollabToolsHaveWorkedWith'].str.split(';')
df_filt = df_filt.explode('NEWCollabToolsHaveWorkedWith')
df_filt['NEWCollabToolsHaveWorkedWith'] = df_filt['NEWCollabToolsHaveWorkedWith'].str.strip()

# %%
counts = df_filt['NEWCollabToolsHaveWorkedWith'].value_counts()
counts = counts[0:11]
labels = counts.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*counts/counts.sum()
patches, texts = plt.pie(counts,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, counts),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("Top10 Collab Tools Distribution")

# Display the chart
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
df.dropna(subset=['LanguageAdmired'], inplace=True)
df_filt = df[['LanguageAdmired']].copy() 
df_filt['LanguageAdmired'] = df_filt['LanguageAdmired'].str.split(';')
df_filt = df_filt.explode('LanguageAdmired')
df_filt['LanguageAdmired'] = df_filt['LanguageAdmired'].str.strip()

# %%
counts = df_filt['LanguageAdmired'].value_counts()
counts = counts[0:6]
labels = counts.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*counts/counts.sum()
patches, texts = plt.pie(counts,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, counts),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("Top5 Programming Language Distribution")

# Display the chart
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
df['AIToolCurrently Using'].unique()
# Out:
# array([nan, 'Writing code;Debugging and getting help',
#        'Writing code;Debugging and getting help;Search for answers', ...,
#        'Writing code;Debugging and getting help;Testing code;Committing and reviewing code;Search for answers;Generating content or synthetic data;Other (please specify):',
#        'Learning about a codebase;Project planning;Writing code;Testing code;Committing and reviewing code;Search for answers;Generating content or synthetic data;Other (please specify):',
#        'Learning about a codebase;Writing code;Committing and reviewing code;Deployment and monitoring;Predictive analytics;Search for answers'],
#       shape=(1168,), dtype=object)

# %%
##Write your code here
df.dropna(subset=['AIToolCurrently Using'], inplace=True)
df_filt = df[['AIToolCurrently Using']].copy() 
df_filt['AIToolCurrently Using'] = df_filt['AIToolCurrently Using'].str.split(';')
df_filt = df_filt.explode('AIToolCurrently Using')
df_filt['AIToolCurrently Using'] = df_filt['AIToolCurrently Using'].str.strip()

# %%
counts = df_filt['AIToolCurrently Using'].value_counts()
counts = counts[0:6]
labels = counts.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*counts/counts.sum()
patches, texts = plt.pie(counts,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, counts),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("Top5 AI Tools Distribution")

# Display the chart
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
df.dropna(subset=['WebframeWantToWorkWith'], inplace=True)
df_filt = df[['WebframeWantToWorkWith']].copy() 
df_filt['WebframeWantToWorkWith'] = df_filt['WebframeWantToWorkWith'].str.split(';')
df_filt = df_filt.explode('WebframeWantToWorkWith')
df_filt['WebframeWantToWorkWith'] = df_filt['WebframeWantToWorkWith'].str.strip()

# %%
counts = df_filt['WebframeWantToWorkWith'].value_counts()
counts = counts[0:6]
labels = counts.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*counts/counts.sum()
patches, texts = plt.pie(counts,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, counts),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("Top5 WebFrame Tools Distribution")

# Display the chart
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
##Write your code here
df.dropna(subset=['EmbeddedWantToWorkWith'], inplace=True)
df_filt = df[['EmbeddedWantToWorkWith']].copy() 
df_filt['EmbeddedWantToWorkWith'] = df_filt['EmbeddedWantToWorkWith'].str.split(';')
df_filt = df_filt.explode('EmbeddedWantToWorkWith')
df_filt['EmbeddedWantToWorkWith'] = df_filt['EmbeddedWantToWorkWith'].str.strip()

# %%
counts = df_filt['EmbeddedWantToWorkWith'].value_counts()
counts = counts[0:6]
labels = counts.index

# %%
# Create a figure and axes with a specific size
porcent = 100.*counts/counts.sum()
patches, texts = plt.pie(counts,  startangle=90, radius=1.2)
labels = ['{0} - {1:1.2f} %'.format(i,j) for i,j in zip(labels, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, counts),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='center right', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)
# Add a title
plt.title("Top5 Embedded Tools Distribution")

# Display the chart
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
